# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#나머지 특성들로 독성인지 아닌지를 판별하는 머신러닝 만들기

mushroom_df=pd.read_csv('mushrooms.csv')

mushroom_df.head(3)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# ...

# %% [markdown]
# About this file
#
# Attribute Information: (classes: edible=e, poisonous=p)
# (속성 정보: 먹을 수 있다=e, 독성 있다=p)
#
# cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# (버섯 머리 모양: bell = b, conical = c, convex = x, flat = f, knobbed = k, sunken = s)
#
# cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# (버섯 머리 표면: 섬유질 = f, 홈 = g, 비늘 = y, 부드러움 = s)
#
# cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# (버섯 머리 색: 갈색 = n, 담황색 = b, 계피 = c, 회색 = g, 녹색 = r, 분홍색 = p, 보라색 = u, 빨간색 = e, 흰색 = w, 노란색 = y)
#
# bruises: bruises=t,no=f
# (타박상: true=t, false=f)
#
# odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
# (냄새: 아몬드 = a, 아니스 = l, 크레오소트 = c, 비린내 = y, 파울 = f, 곰팡이 = m, 없음 = n, 매운맛 = p, 매운 = s)
#
# gill-attachment: attached=a,descending=d,free=f,notched=n
# (아가미 부착 : 부착 = a, 내림차순 = d, 자유 = f, 노치 = n)
#
# gill-spacing: close=c,crowded=w,distant=d
# (아가미 간격 : close = c, crowded = w, distant = d)
#
# gill-size: broad=b,narrow=n
# (아가미 크기 : broad = b, narrow = n)
#
# gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
# (아가미..? 색상: 검정 = k, 갈색 = n, 담황색 = b, 초콜릿 = h, 회색 = g, 녹색 = r, 주황색 = o, 분홍색 = p, 보라색 = u, 빨간색 = e, 흰색 = w, 노란색 = 와이)
#
# stalk-shape: enlarging=e,tapering=t
# (줄기 모양 : 확대 = e, 테이퍼링 = t)
#
# stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
# (스토킹 루트 : 구근 = b, 클럽 = c, 컵 = u, 같음 = e, rhizomorphs = z, rooted = r, missing =?)
#
# stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# (줄기 표면 위 링 : 섬유질 = f, 스케 리 = y, 실키 = k, 부드러움 = s)
#
# stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# (줄기 표면 아래 링 : 섬유질 = f, 스케 리 = y, 실키 = k, 부드러움 = s)
#
# stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# (줄기-색상-링 위 : 갈색 = n, 버프 = b, 계피 = c, 회색 = g, 주황색 = o, 분홍색 = p, 빨간색 = e, 흰색 = w, 노란색 = y)
#
# stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# (줄기 색상-링 아래 : 갈색 = n, 버프 = b, 시나몬 = c, 회색 = g, 주황색 = o, 분홍색 = p, 빨간색 = e, 흰색 = w, 노란색 = y)
#
# veil-type: partial=p,universal=u
# (베일 유형 : partial = p, universal = u)
#
# veil-color: brown=n,orange=o,white=w,yellow=y
# (베일 색상 : 갈색 = n, 주황색 = o, 흰색 = w, 노란색 = y)
#
# ring-number: none=n,one=o,two=t
# (링 번호 : none = n, one = o, two = t)
#
# ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
# (링 유형 : 거미줄 = c, 소멸 = e, 불꽃 = f, 대 = l, 없음 = n, 펜던트 = p, sheathing = s, zone = z)
#
# spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
# (포자 인쇄 색상 : 검정 = k, 갈색 = n, 버프 = b, 초콜릿 = h, 녹색 = r, 주황색 = o, 보라색 = u, 흰색 = w, 노란색 = y)
#
# population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
# (인구 : abundant = a, clustered = c, numerous = n, scattered = s, several = v, solitary = y)
#
# habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d
# (서식지 : grasses = g, leaves = l, meadows = m, paths = p, urban = u, waste = w, woods = d)

# %%
print("\n ### train 데이터 정보 ###\n")
print(mushroom_df.info())
# Out:
#  ### train 데이터 정보 ###
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# Null 처리

# %%
#널값 확인 : 널값이 없으니 널 처리는 하지 않음
mushroom_df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
print(' class 값 분포:\n', mushroom_df['class'].value_counts())
print('\n cap-shape 값 분포:\n', mushroom_df['cap-shape'].value_counts())
# Out:
#  class 값 분포:
#  e    4208
# p    3916
# Name: class, dtype: int64
#
#  cap-shape 값 분포
#  x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
mushroom_df.groupby(['population', 'class'])['class'].count()
# Out:
# population  class
# a           e         384
# c           e         288
#             p          52
# n           e         400
# s           e         880
#             p         368
# v           e        1192
#             p        2848
# y           e        1064
#             p         648
# Name: class, dtype: int64

# %%
# sns.barplot(x='population', y = 'class', data=mushroom_df)

# %%
#문자를 숫자로 만듦
from sklearn import preprocessing

def encode_features(dataDF):
    features = mushroom_df.columns
    for feature in features:
        le = preprocessing.LabelEncoder()
        le = le.fit(dataDF[feature])
        dataDF[feature] = le.transform(dataDF[feature])
        
    return dataDF

mushroom_df = encode_features(mushroom_df)
mushroom_df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
y_mushroom_df=mushroom_df['class']
X_mushroom_df=mushroom_df.drop('class', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_mushroom_df, y_mushroom_df, \
                                                  test_size=0.2, random_state=11)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 결정트리, Random Forest, 로지스틱 회귀를 위한 사이킷런 Classifier 클래스 생성
dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()

# DecisionTreeClassifier 학습/예측/평가
dt_clf.fit(X_train , y_train)
dt_pred = dt_clf.predict(X_test)
print('DecisionTreeClassifier 정확도: {0:.4f}'.format(accuracy_score(y_test, dt_pred)))

# RandomForestClassifier 학습/예측/평가
rf_clf.fit(X_train , y_train)
rf_pred = rf_clf.predict(X_test)
print('RandomForestClassifier 정확도:{0:.4f}'.format(accuracy_score(y_test, rf_pred)))

# LogisticRegression 학습/예측/평가
lr_clf.fit(X_train , y_train)
lr_pred = lr_clf.predict(X_test)
print('LogisticRegression 정확도: {0:.4f}'.format(accuracy_score(y_test, lr_pred)))
# Out:
# DecisionTreeClassifier 정확도: 1.0000
# RandomForestClassifier 정확도:1.0000
# LogisticRegression 정확도: 0.9397
# /Users/kim-yuyeon/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.model_selection import KFold

def exec_kfold(clf, folds=5):
    # 폴드 세트를 5개인 KFold객체를 생성, 폴드 수만큼 예측결과 저장을 위한  리스트 객체 생성.
    kfold = KFold(n_splits=folds)
    scores = []
    
    # KFold 교차 검증 수행. 
    for iter_count , (train_index, test_index) in enumerate(kfold.split(X_mushroom_df)):
        # X_titanic_df 데이터에서 교차 검증별로 학습과 검증 데이터를 가리키는 index 생성
        X_train, X_test = X_mushroom_df.values[train_index], X_mushroom_df.values[test_index]
        y_train, y_test = y_mushroom_df.values[train_index], y_mushroom_df.values[test_index]
        
        # Classifier 학습, 예측, 정확도 계산 
        clf.fit(X_train, y_train) 
        predictions = clf.predict(X_test)
        accuracy = accuracy_score(y_test, predictions)
        scores.append(accuracy)
        print("교차 검증 {0} 정확도: {1:.4f}".format(iter_count, accuracy))     
    
    # 5개 fold에서의 평균 정확도 계산. 
    mean_score = np.mean(scores)
    print("평균 정확도: {0:.4f}".format(mean_score)) 
# exec_kfold 호출
exec_kfold(dt_clf , folds=5)
# Out:
# 교차 검증 0 정확도: 1.0000
# 교차 검증 1 정확도: 1.0000
# 교차 검증 2 정확도: 1.0000
# 교차 검증 3 정확도: 0.9865
# 교차 검증 4 정확도: 0.9606
# 평균 정확도: 0.9894

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(dt_clf, X_mushroom_df , y_mushroom_df , cv=5)
for iter_count,accuracy in enumerate(scores):
    print("교차 검증 {0} 정확도: {1:.4f}".format(iter_count, accuracy))

print("평균 정확도: {0:.4f}".format(np.mean(scores)))
# Out:
# 교차 검증 0 정확도: 0.8425
# 교차 검증 1 정확도: 1.0000
# 교차 검증 2 정확도: 1.0000
# 교차 검증 3 정확도: 1.0000
# 교차 검증 4 정확도: 0.7192
# 평균 정확도: 0.9123

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'max_depth':[2,3,5,10],
             'min_samples_split':[2,3,5], 'min_samples_leaf':[1,5,8]}

grid_dclf = GridSearchCV(dt_clf , param_grid=parameters , scoring='accuracy' , cv=5)
grid_dclf.fit(X_train , y_train)

print('GridSearchCV 최적 하이퍼 파라미터 :',grid_dclf.best_params_)
print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_dclf.best_score_))
best_dclf = grid_dclf.best_estimator_

# GridSearchCV의 최적 하이퍼 파라미터로 학습된 Estimator로 예측 및 평가 수행. 
dpredictions = best_dclf.predict(X_test)
accuracy = accuracy_score(y_test , dpredictions)
print('테스트 세트에서의 DecisionTreeClassifier 정확도 : {0:.4f}'.format(accuracy))
# Out:
# GridSearchCV 최적 하이퍼 파라미터 : {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# GridSearchCV 최고 정확도: 1.0000
# 테스트 세트에서의 DecisionTreeClassifier 정확도 : 1.0000
